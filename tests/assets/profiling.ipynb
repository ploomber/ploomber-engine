# %%
import time
import numpy as np

# %%
time.sleep(5)

# %%
x = np.random.rand(100)

# %%
time.sleep(5)

# %%
y = np.random.rand(1_000_000)

# %%
time.sleep(5)

# %%
y = np.random.rand(10_000_000)

# %%
time.sleep(5)
